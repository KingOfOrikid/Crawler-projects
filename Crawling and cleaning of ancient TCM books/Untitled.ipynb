# %%
import json

# %%
d=[]
with open('普济方（四库本361-426卷）.txt','r',encoding='utf-8') as f:
    a=f.readlines()
    d.extend(a)

# %%
data={}
temp=[]
for i in d:
    i=i.replace('\n','')
    if i!='':
        if i=='<子部,医家类,普济方>':
            text=temp[0]+' '+temp[1].split()[-1]
            data[text]=temp
            del data[text][0]
            del data[text][0]
            del data[text][-1]
            temp=[]
        else:
            temp.append(i)

# %%
for key in data.keys():
    for i in range(0,len(data[key])):
        data[key][i]=data[key][i].strip()

# %%
#总论
dic={}
index=0
for key in data.keys():
    temp=[]
    index=0
    for i in range(1,len(data[key])):
        if '总论' in data[key][i] or '附论' in data[key][i] or '緫论'in data[key][i]:
            temp.append(data[key][index:i])
            index=i
    temp.append(data[key][index:])
    dic[key]=temp
    temp=[]

# %%
#保存
filename='test5.16.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.16.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    con=dic[key]
    temp={}
    for item in con:
        if '方' in item:
            index=item.index('方')
            temp[item[0]]={}
            temp[item[0]]['论']=item[1:index]
            temp[item[0]]['方']=item[index+1:]
        elif '方' not in item:
            temp[item[0]]={}
            temp[item[0]]['论']=item[1]
            temp[item[0]]['方']=item[2:]
    dic[key]=temp

# %%
#保存
filename='test5.16_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# ## 5.17

# %%
#读取json中爬取的数据
with open('test5.16_2.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name]:
            item=dic[key][name]['方']
            temp=[]
            for i in range(0,len(item)):
                if '方】' in item[i] or '书】' in item[i] or '　治' in item[i] or '】治' in item[i] or '散　' in item[i]:
                    temp.append('*')
                    temp.append(item[i])
                else:
                    temp.append(item[i])
            dic[key][name]['方']=temp

# %%
#保存
filename='test5.17.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name] and dic[key][name]['方']!=[]:
            item=dic[key][name]['方']
            temp=[]
            for i in range(0,len(item)-1):
                if item[i][0]=='右' and '又方' not in item[i+1] and '*' !=item[i+1]:
                    temp.append(item[i])
                    temp.append('*')
                else:
                    temp.append(item[i])
            temp.append(item[-1])
            dic[key][name]['方']=temp

# %%
#保存
filename='test5.17.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name] and dic[key][name]['方']!=[]:
            item=dic[key][name]['方']
            temp=[]
            temp.append(item[0])
            for i in range(1,len(item)-1):
                if item[i][0]=='治' and item[i-1]!='*':
                    temp.append('*')
                    temp.append(item[i])
                else:
                    temp.append(item[i])
            temp.append(item[-1])
            dic[key][name]['方']=temp

# %%
#保存
filename='test5.17.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name] and dic[key][name]['方']!=[]:
            item=dic[key][name]['方']
            temp=[]
            temp.append(item[0])
            for i in range(1,len(item)-1):
                if item[i][0]=='疗' and item[i-1]!='*':
                    temp.append('*')
                    temp.append(item[i])
                else:
                    temp.append(item[i])
            temp.append(item[-1])
            dic[key][name]['方']=temp

# %%
#保存
filename='test5.17.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name] and dic[key][name]['方']!=[]:
            item=dic[key][name]['方']
            temp=[]
            for i in range(0,len(item)-1):
                if '又方'==item[i+1][:2] and item[i]=='*':
                    pass
                else:
                    temp.append(item[i])
            temp.append(item[-1])
            dic[key][name]['方']=temp

# %%
#保存
filename='test5.17.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#药方分成一个一个列表
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name] and dic[key][name]['方']!=[]:
            item=dic[key][name]['方']
            temp=[]
            index=0
            for i in range(1,len(item)):
                if item[i]=='*':
                    temp.append(item[index+1:i])
                    index=i
            temp.append(item[index+1:])
            dic[key][name]['方']=temp

# %%
#保存
filename='test5.17_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# ## 5.19

# %%
#读取json中爬取的数据
with open('test5.17_2.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '方' in dic[key][name] and dic[key][name]['方']!=[]:
            item=dic[key][name]['方']
            dic[key][name]['临时方']=[]
            dic[key][name]['药方']=[]
            #按行数判断方是规则三行/两行 还是多行方 多行的话放入临时方进行另外处理
            for i in range(0,len(item)):
                temp={}
                if len(item[i])==3:
                    if '　治' in item[i][0]:
                        index=item[i][0].index('　治')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index+1:]
                    elif '】治' in item[i][0]:
                        index=item[i][0].index('【')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index:]
                    elif '散　' in item[i][0]:
                        index=item[i][0].index('散　')
                        temp['方名']=item[i][0][:index+1]
                        temp['主治']=item[i][0][index+2:]
                    elif '方】' in item[i][0]:
                        index=item[i][0].index('【')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index:]
                    elif '书】' in item[i][0]:
                        index=item[i][0].index('【')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index:]
                    elif '【出' in item[i][0]:
                        index=item[i][0].index('【')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index:]
                    elif '　疗' in item[i][0]:
                        index=item[i][0].index('　疗')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index+1:]
                    elif '治' in item[i][0]:
                        index=item[i][0].index('治')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index:]
                    elif '疗' in item[i][0]:
                        index=item[i][0].index('疗')
                        temp['方名']=item[i][0][:index]
                        temp['主治']=item[i][0][index:]
                    elif '　' not in item[i][0] and '【' not in item[i][0]:
                        temp['方名']=item[i][0]
                    else:
                        if '　' in item[i][0]:
                            index=item[i][0].index('　')
                            temp['方名']=item[i][0][:index]
                            temp['主治']=item[i][0][index+1:]
                        elif '【' in item[i][0]:
                            index=item[i][0].index('【')
                            temp['方名']=item[i][0][:index]
                            temp['主治']=item[i][0][index:]
                        else:
                            print(item[i][0])
                    temp['中药剂量']=item[i][1]
                    temp['用法']=item[i][2]
                elif len(item[i])==2:
                    if '治'==item[i][0][0] or '疗'==item[i][0][0]:
                        if '又方' not in item[i][1]:
                            if item[i][0].count('【')<=1:
                                if item[i][0].count('【')==1:
                                    index=item[i][0].index('【')
                                    temp['方名']=item[i][0][:index]
                                    temp['用法']=item[i][0][index:]+item[i][1]
                                else:
                                    temp['方名']=item[i][0]
                                    temp['用法']=item[i][1]
                            else:
                                #pass
                                dic[key][name]['临时方'].append(item[i])
                        else:
                            #pass
                            dic[key][name]['临时方'].append(item[i])
                    else:
                        if '【' not in item[i][0] and '　' not in item[i][0]:
                            if '治' in item[i][0]:
                                index=item[i][0].index('治')
                                temp['方名']=item[i][0][:index]
                                temp['主治']=item[i][0][index:]
                                temp['用法']=item[i][1]
                            elif '疗' in item[i][0]:
                                index=item[i][0].index('疗')
                                temp['方名']=item[i][0][:index]
                                temp['主治']=item[i][0][index:]
                                temp['用法']=item[i][1]
                            else:
                                temp['方名']=item[i][0]
                                temp['用法']=item[i][1]
                        else:
                            if '】' ==item[i][0][-1] and item[i][0].count('】')==1 and item[i][1][0]=='右' and '　' not in item[i][0]:
                                index=item[i][0].index('【')
                                temp['方名']=item[i][0][:index]
                                temp['用法']=item[i][0][index:]+item[i][1]
                            elif '治' in item[i][0] and '【' not in item[i][0] and '【' not in item[i][1]:
                                index=item[i][0].index('治')
                                temp['方名']=item[i][0][:index]
                                temp['主治']=item[i][0][index:]
                                temp['用法']=item[i][1]
                            else:
                                dic[key][name]['临时方'].append(item[i])
                                #pass
                else:
                    dic[key][name]['临时方'].append(item[i])
                if temp!={}:
                    dic[key][name]['药方'].append(temp)
            del dic[key][name]['方']

# %%
filename='test5.19.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# #下一步 先分特殊方：
# 只有一行的 按 】和右划分
# 多行的 判断有没有又方

# %% [markdown]
# ## 5.21 分一行的

# %%
#读取json中爬取的数据
with open('test5.19.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if len(i)==1:
                    temp_i=[]
                    index=0
                    temp=''
                    if '治'!=i[0][0] and '疗'!=i[0][0]:
                        if '【出' in i[0]:
                            index=i[0].index('【出')
                            temp_i.append(i[0][:index].strip())
                        elif '方】' in i[0]:
                            index=i[0].index('【')
                            temp_i.append(i[0][:index].strip())
                        elif '书】' in i[0]:
                            index=i[0].index('【')
                            temp_i.append(i[0][:index].strip())
                        elif '【一名' in i[0]:
                            index=i[0].index('【一名')
                            temp_i.append(i[0][:index].strip())
                        elif '　治' in i[0]:
                            index=i[0].index('　治')
                            temp_i.append(i[0][:index].strip())
                            
                        if '右' in i[0][index:]:
                            index2=i[0][index:].index('右')
                            temp_i.append(i[0][index:][:index2].strip())
                            temp_i.append(i[0][index:][index2:].strip())
                        elif '【方见' in i[0][index:]:
                            index2=i[0][index:].index('【方见')
                            temp_i.append(i[0][index:][:index2].strip())
                            temp_i.append(i[0][index:][index2:].strip())
                        elif '　用' in i[0][index:]:
                            index2=i[0][index:].index('　用')
                            temp_i.append(i[0][index:][:index2].strip())
                            temp_i.append(i[0][index:][index2:].strip())
                        elif '　以' in i[0][index:]:
                            index2=i[0][index:].index('　以')
                            temp_i.append(i[0][index:][:index2].strip())
                            temp_i.append(i[0][index:][index2:].strip())
                        else:
                            temp_i.append(i[0][index:].strip())
                            
                        if len(temp_i)==3:
                            temp_dic={}
                            temp_dic['药方']=temp_i[0]
                            temp_dic['主治']=temp_i[1]
                            temp_dic['用法']=temp_i[2]
                            dic[key][name]['药方'].append(temp_dic)
                        else:
                            temp_con.append(i)
                    else:
                        temp_con.append(i)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.19_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if len(i)==1:
                    temp_i={}
                    if '治'==i[0][0]:
                        if '【出' in i[0]:
                            index=i[0].index('【出')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '书】' in i[0]:
                            index=i[0].index('【')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '　' in i[0]:
                            index=i[0].index('　')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '【方见' in i[0]:
                            index=i[0].index('【')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '右' in i[0]:
                            index=i[0].index('右')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        else:
                            temp_con.append(i)
                    elif '疗'==i[0][0]:
                        if '【出' in i[0]:
                            index=i[0].index('【出')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '书】' in i[0]:
                            index=i[0].index('【')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '　' in i[0]:
                            index=i[0].index('　')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '【方见' in i[0]:
                            index=i[0].index('【')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        elif '右' in i[0]:
                            index=i[0].index('右')
                            temp_i['方名']=i[0][:index].strip()
                            temp_i['用法']=i[0][index:].strip()
                        else:
                            temp_con.append(i)
                    else:
                        temp_con.append(i)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.19_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if len(i)==1:
                    temp_dic={}
                    if '【出' in i[0]:
                        index=i[0].index('【出')
                        temp_dic['方名']=i[0][:index]
                        i[0]=i[0].replace('】　','】')
                        if '宜用' in i[0][index:].strip():
                            index2=i[0][index:].strip().index('宜用')
                            temp_dic['主治']=i[0][index:][:index2]
                            temp_dic['用法']=i[0][index:][index2:]
                        elif '用' in i[0][index:].strip():
                            index2=i[0][index:].strip().index('用')
                            temp_dic['主治']=i[0][index:][:index2]
                            temp_dic['用法']=i[0][index:][index2:]
                        elif '　' in i[0][index:].strip():
                            index2=i[0][index:].strip().index('　')
                            temp_dic['主治']=i[0][index:][:index2]
                            temp_dic['用法']=i[0][index:][index2:]
                        elif '以' in i[0][index:].strip():
                            index2=i[0][index:].strip().index('以')
                            temp_dic['主治']=i[0][index:][:index2]
                            temp_dic['用法']=i[0][index:][index2:]
                        elif '右' in i[0][index:].strip():
                            index2=i[0][index:].strip().index('右')
                            temp_dic['主治']=i[0][index:][:index2]
                            temp_dic['用法']=i[0][index:][index2:]
                    else:
                        temp_con.append(i)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.19_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# ## 5.31

# %%
#读取json中爬取的数据
with open('test5.31.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if len(i)==1:
                    temp=i[0].split('　')
                    if len(temp)==3:
                        temp_dic={}
                        temp_dic['方名']=temp[0]
                        temp_dic['主治']=temp[1]
                        temp_dic['用法']=temp[2]
                    elif len(temp)==2:
                        temp_dic={}
                        temp_dic['方名']=temp[0]
                        if '【方见' in temp[1]:
                            index=temp[1].index('【方见')
                            temp_dic['主治']=temp[1][:index]
                            temp_dic['用法']=temp[1][index:]
                        elif '方见' in temp[1]:
                            index=temp[1].index('方见')
                            temp_dic['主治']=temp[1][:index]+'】'
                            temp_dic['用法']='【'+temp[1][index:]
                        elif '方在' in temp[1]:
                            index=temp[1].index('方在')
                            temp_dic['主治']=temp[1][:index]+'】'
                            temp_dic['用法']='【'+temp[1][index:]
                    elif len(temp)==1:
                        temp_dic={}
                        index1=temp[0].index('治')
                        if '【' in temp[0]:
                            index2=temp[0].index('【')
                        else:
                            index2=temp[0].index('以')
                        temp_dic['方名']=temp[0][:index1]
                        temp_dic['主治']=temp[0][index1:index2]
                        temp_dic['用法']=temp[0][index2:]
                        
                    dic[key][name]['药方'].append(temp_dic)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.31_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '药方' in con[i]:
                    dic[key][name]['药方'][i]['方名']=dic[key][name]['药方'][i]['药方']
                    del dic[key][name]['药方'][i]['药方']

# %%
filename='test5.31_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_2.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if len(i)==2:
                    if '又方' not in i[1] and '又方' not in i[0]:
                        if '右'==i[1][0]:
                            if i[0].count('【')==1:
                                index=i[0].index('【')
                                temp_dic={}
                                temp_dic['方名']=i[0][:index]
                                temp_dic['主治']=i[0][index:]
                                temp_dic['用法']=i[1]
                                dic[key][name]['药方'].append(temp_dic)
                            else:
                                temp_con.append(i)
                        else:
                            temp_con.append(i)
                    else:
                        temp_con.append(i)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                temp_dic={}
                if len(i)==2:
                    if '又方' not in i[1] and '又方' not in i[0]:
                        if '用'==i[1][0]:
                            index=i[0].index('【')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:]
                            temp_dic['用法']=i[1]
                if temp_dic=={}:
                    temp_con.append(i)
                else:
                    dic[key][name]['药方'].append(temp_dic)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.31_3.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                temp_dic={}
                if len(i)==2:
                    if '又方' not in i[1] and '又方' not in i[0]:
                        if '　治' in i[0]:
                            index=i[0].index('　')
                            index=index+1
                        elif '【出' in i[0]:
                            index=i[0].index('【出')
                        else:
                            index=0
                        
                        if '宜服此方大有功效' in i[0][index:]:
                            index2=i[0][index:].index('宜服此方大有功效')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:][:index2+8]
                            temp_dic['中药剂量']=i[0][index:][index2+8:]
                            temp_dic['用法']=i[1]
                        elif '常服此佳' in i[0][index:]:
                            index2=i[0][index:].index('常服此佳')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:][:index2+4]
                            temp_dic['中药剂量']=i[0][index:][index2+4:]
                            temp_dic['用法']=i[1]
                        elif '宜服此方' in i[0][index:]:
                            index2=i[0][index:].index('宜服此方')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:][:index2+4]
                            temp_dic['中药剂量']=i[0][index:][index2+4:]
                            temp_dic['用法']=i[1]
                        elif '宜服此药' in i[0][index:]:
                            index2=i[0][index:].index('宜服此药')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:][:index2+4]
                            temp_dic['中药剂量']=i[0][index:][index2+4:]
                            temp_dic['用法']=i[1]
                        elif '宜服之' in i[0][index:]:
                            index2=i[0][index:].index('宜服之')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:][:index2+3]
                            temp_dic['中药剂量']=i[0][index:][index2+3:]
                            temp_dic['用法']=i[1]
                        elif '宜服' in i[0][index:]:
                            index2=i[0][index:].index('宜服')
                            temp_dic['方名']=i[0][:index]
                            temp_dic['主治']=i[0][index:][:index2+2]
                            temp_dic['中药剂量']=i[0][index:][index2+2:]
                            temp_dic['用法']=i[1]

                if temp_dic=={}:
                    temp_con.append(i)
                else:
                    dic[key][name]['药方'].append(temp_dic)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.31_3.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_3.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
def change():
    for key in dic.keys():
        for name in dic[key].keys():
            if '临时方' in dic[key][name]:
                con=dic[key][name]['临时方']
                temp_con=[]
                for i in range(0,len(con)):
                    temp_dic={}
                    if len(con[i])==2:
                        if '又方' not in con[i][1] and '又方' not in con[i][0]:
                            print(con[i][0])
                            st=input()
                            if st=='n':
                                continue
                            elif st=='del':
                                dic[key][name]['临时方'][i]=[]
                            elif st=='q':
                                return
                            else:
                                index=con[i][0].index(st)
                                temp=[]
                                temp.append(con[i][0][:index])
                                temp.append(con[i][0][index:])
                                temp.append(con[i][1])
                                dic[key][name]['临时方'][i]=temp

# %%
filename='test5.31_4.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
change()
# Out:
# 大黄散　治小儿阳毒伤寒未解热结在内恍惚如狂大黄【一两】桂心【三分】甘草　木通　大腹皮【各一两】芒硝【七两】桃仁【二十一粒去皮尖麸炒】
# 大黄【一两】桂心【三分】甘
# 和解汤　治小儿四时感冐寒邪壮热烦渴鼻塞多涕惊悸自汗肢节疼痛及肤疮豆已发未发者皆可服羗活　防风　川芎　人参【各一两】干葛　川升麻【轻者】甘草【微炒各半两】
# 羗活　防风　川芎
# 柴胡散　治小儿伤寒壮热头疼体痛口干烦渴石膏　黄芩　甘草　赤芍药　葛根【各一两】麻黄【去根节】柴胡【去苗各半两】
# 石膏　黄芩　甘草　赤芍药
# 乳香丸　治小儿百日内患伤寒壮热速宜疗之铧铁【一斤烧令通赤以水二斗淬之如此三七遍煎取二停更入柳叶七片淬而又用】胡油麻【二十一粒】松栢叶【二七枝】牙硝　乳香【各一分】金箔白芥子【二七粒】
# 铧铁【一斤烧令通赤以水二斗淬之如此三七遍煎取二停更入柳叶七片淬而又用】胡油
# 细辛散　治小儿大人头疼及伤寒壮热头风明目细辛　石膏　何首乌【各一分】川乌头　川芎　干薄荷【各半两】蝎【十四个】
# 细辛　石膏　何首乌【各一
# 知母麻黄汤　治伤寒瘥后或十数日半月二十日终不惺惺昏沉似失精神言语错缪又无寒热医者或作鬼祟或作风疾多治不瘥或朝夕潮热额赤或有寒热似疟都是发汗不尽余毒在心包络间所致知母【一两半】麻黄【去节】甘草　赤芍药　黄芩【各半两】桂枝【半两夏月减半】
# 知母【一两半】麻黄【去节】
# 人参散　治伤寒潮热鼻塞头疼亦治清涕壮热不解人参　茯苓　羗活　当归　前胡　甘草【各一钱】麻黄【三钱去节】
# 人参　茯苓　羗活　当归　前胡
# 麦煎散　治四时伤寒头痛发热气喘痰能利肺经化痰涎止喘功効甚速凢伤寒者便可服之人参【去芦】白茯苓　苦桔梗【去芦】杏仁【不去皮各五钱】白术柴胡【去芦】知母　贝母【去心】麻黄【去节根】甘草　葶苈【炒】桑白皮【蜜炙各三钱】秋冬加桂枝半夏曲五钱
# 人参【去芦】白茯苓　苦桔梗【去芦】杏
# 治小儿伤寒后余热不除四肢不利宜用此汤浴川大黄　甘草　防风【去芦头】丹参【各半两】雷丸【三分】白术【半两】
# 川大黄　甘草　防风【去芦
# 犀角散　治小儿百日已来伤寒挟实壮热多惊心躁犀角屑　川朴硝　龙胆【各一分去芦头】川大黄【半两剉碎微炒】甘草【炙微赤剉】枳殻【各一分麸炒微黄去瓤】
# 犀角屑　川朴硝　龙胆【各一分去芦
# ...

# %%
filename='test5.31_4.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_4.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                temp_dic={}
                if len(i)==3:
                    if '　治' in i[0]:
                        index=i[0].index('　治')
                    elif '【' in i[0]:
                        index=i[0].index('【')
                    if '【' in i[0][:index]:
                        index=i[0].index('【')
                    temp_dic['方名']=i[0][:index].strip()
                    temp_dic['主治']=i[0][index:].strip()
                    temp_dic['中药剂量']=i[1]
                    temp_dic['用法']=i[2]
                if temp_dic!={}:
                    dic[key][name]['药方'].append(temp_dic)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.31_5.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_5.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if len(i)==2:
                    temp_dic={}
                    if '　' in i[0]:
                        index1=i[0].index('　')
                    
                    if '【' in i[0][:index1]:
                        index1=i[0].index('【')
                    temp_dic['方名']=i[0][:index1].strip()
                    temp_dic['用法']=i[0][index1:].strip()
                    
                    
                    if '　' in i[1]:
                        index2=i[1].index('　')
                    temp_dic['又方']=[]
                    you={}
                    you['方名']=i[1][:index2].replace('又方','').strip()
                    if you['方名']=='':
                        del you['方名']
                    you['用法']=i[1][index2:].strip()
                    temp_dic['又方'].append(you)
                    
                    dic[key][name]['药方'].append(temp_dic)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.31_6.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_6.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name] and dic[key][name]['临时方']==[]:
            del dic[key][name]['临时方']

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if con[i]['方名']=='':
                    dic[key][name]['药方'][i]['方名']=dic[key][name]['药方'][i]['主治']
                    del dic[key][name]['药方'][i]['主治']

# %%
filename='test5.31_6.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_6.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                temp_dic={}
                if len(i)==4 and '又方' not in i[2]:
                    if '【' in i[1] and '【' in i[2]:
                        if '　治' in i[0]:
                            index=i[0].index('　治')
                            if '【' in i[0][:index]:
                                index=i[0].index('【')
                        elif '【' in i[0]:
                            index=i[0].index('【')
                        elif '治' in i[0]:
                            index=i[0].index('治')
                        elif '　' in i[0]:
                            index=i[0].index('　')
                        else:
                            index=0
                        temp_dic['方名']=i[0][:index].strip()
                        temp_dic['主治']=i[0][index:].strip()
                        temp_dic['中药剂量']=(i[1]+i[2]).strip()
                        temp_dic['用法']=i[3].strip()
                        
                if temp_dic=={}:
                    temp_con.append(i)
                else:
                    dic[key][name]['药方'].append(temp_dic)

# %%
filename='test5.31_6.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# ## 6.1 多行又方划分 中药切分

# %%
#读取json中爬取的数据
with open('test5.31_6.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for ii in range(0,len(con)):
                i=con[ii]
                if len(i)==4 and '又方' not in i[2]:
                    if '【' in i[1] and '【' in i[2]:
                        pass
                    else:
                        temp_con.append(i)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test5.31_6.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test5.31_6.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
new_dic={}
for key in dic.keys():
    new_dic[key]={}
    for name in dic[key].keys():
        new_dic[key][name]=[]
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in con:
                if '治'==i[0][0] or '疗'==i[0][0]:
                    new_dic[key][name].append(i)
                else:
                    temp_con.append(i)
            dic[key][name]['临时方']=temp_con

# %%
filename='test6.1.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
filename='临时6.1.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(new_dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name] and dic[key][name]['临时方']==[]:
            del dic[key][name]['临时方']

# %%
filename='test6.1.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            for i in  range(0,len(con)):
                temp=[]
                if '　治' in con[i][0]:
                    index=con[i][0].index('　治')
                    temp.append(con[i][0][:index].strip())
                    temp.append(con[i][0][index:].strip())
                else:
                    temp.append(con[i][0])
                temp.extend(con[i][1:])
                dic[key][name]['临时方'][i]=temp

# %%
filename='test6.1_2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1_2.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in  range(0,len(con)):
                item=con[i]
                index=0
                for j in range(0,len(item)):
                    if '又方' in item[j]:
                        index=j
                        break
                if index==0:
                    temp_dic={}
                    temp_dic['方名']=item[0]
                    temp_dic['主治']=item[1]
                    temp_dic['中药剂量']=item[2]
                    temp_dic['用法']=item[3]
                    temp_dic['后药']=item[4]
                    temp_dic['后药用法']=item[5]
                    dic[key][name]['药方'].append(temp_dic)
                else:
                    temp_con.append(item)
            dic[key][name]['临时方']=temp_con

# %%
filename='test6.1_3.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1_3.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            for i in range(0,len(con)):
                item=con[i]
                temp=[]
                if '【' in item[0]:
                    index=item[0].index('【')
                    temp.append(item[0][:index])
                    temp.append(item[0][index:])
                    temp.extend(item[1:])
                    dic[key][name]['临时方'][i]=temp

# %%
filename='test6.1_3.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name]:
            con=dic[key][name]['临时方']
            temp_con=[]
            for i in  range(0,len(con)):
                item=con[i]
                index=0
                for j in range(0,len(item)):
                    if '又方' in item[j]:
                        index=j
                        break
                if index!=0:
                    if len(item[:index])==3:
                        temp_dic={}
                        temp_dic['方名']=item[:index][0]
                        temp_dic['主治']=item[:index][1]
                        temp_dic['用法']=item[:index][2]
                        temp_dic['临时又方']=item[index:]
                        dic[key][name]['药方'].append(temp_dic)
                    elif len(item[:index])==4:
                        temp_dic={}
                        temp_dic['方名']=item[:index][0]
                        temp_dic['主治']=item[:index][1]
                        temp_dic['中药剂量']=item[:index][2]
                        temp_dic['用法']=item[:index][3]
                        temp_dic['临时又方']=item[index:]
                        dic[key][name]['药方'].append(temp_dic)
                    else:
                        temp_con.append(item)
                else:
                    temp_con.append(item)
            dic[key][name]['临时方']=temp_con

# %%
filename='test6.1_4.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '临时方' in dic[key][name] and dic[key][name]['临时方']==[]:
            del dic[key][name]['临时方']

# %%
filename='test6.1_4.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1_4.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i]:
                    temp_you=[]
                    if len(con[i]['临时又方'])>3:
                        index=0
                        for j in range(1,len(con[i]['临时又方'])):
                            if con[i]['临时又方'][j]=='又方' or '又方' in con[i]['临时又方'][j]:
                                temp_you.append(con[i]['临时又方'][index:j])
                                index=j
                        dic[key][name]['药方'][i]['临时又方']=temp_you

# %%
filename='test6.1_5.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1_5.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i]:
                    if len(con[i]['临时又方'])==3 and type(con[i]['临时又方'][0])==str:
                        temp_dic={}
                        dic[key][name]['药方'][i]['又方']=[]
                        if '治' in con[i]['临时又方'][0]:
                            temp_dic['主治']=con[i]['临时又方'][0].replace('又方','').strip()
                        elif '】'==con[i]['临时又方'][0][-1]:
                            temp_dic['方名']=con[i]['临时又方'][0].replace('又方','')
                        else:
                            pass
                        temp_dic['中药剂量']=con[i]['临时又方'][1]
                        temp_dic['用法']=con[i]['临时又方'][2]
                        dic[key][name]['药方'][i]['又方'].append(temp_dic)
                        del dic[key][name]['药方'][i]['临时又方']

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i]:
                    if len(con[i]['临时又方'])==2 and type(con[i]['临时又方'][0])==str:
                        temp_dic={}
                        dic[key][name]['药方'][i]['又方']=[]
                        if '治' in con[i]['临时又方'][0]:
                            temp_dic['主治']=con[i]['临时又方'][0].replace('又方','').strip()
                        elif '】'==con[i]['临时又方'][0][-1]:
                            temp_dic['方名']=con[i]['临时又方'][0].replace('又方','')
                        else:
                            pass
                        temp_dic['用法']=con[i]['临时又方'][1]
                        dic[key][name]['药方'][i]['又方'].append(temp_dic)
                        del dic[key][name]['药方'][i]['临时又方']

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i]:
                    temp_item=[]
                    for item in con[i]['临时又方']:
                        if len(item)==2:
                            if '又方' in dic[key][name]['药方'][i]:
                                temp_dic={}
                                if '治' in item[0]:
                                    temp_dic['主治']=item[0].replace('又方','').strip()
                                elif '】' ==item[0][-1]:
                                    temp_dic['方名']=item[0].replace('又方','')
                                else:
                                    pass
                                temp_dic['用法']=item[1]
                                dic[key][name]['药方'][i]['又方'].append(temp_dic)
                            else:
                                dic[key][name]['药方'][i]['又方']=[]
                                temp_dic={}
                                if '治' in item[0]:
                                    temp_dic['主治']=item[0].replace('又方','').strip()
                                elif '】' ==item[0][-1]:
                                    temp_dic['方名']=item[0].replace('又方','')
                                else:
                                    pass
                                temp_dic['用法']=item[1]
                                dic[key][name]['药方'][i]['又方'].append(temp_dic)
                        else:
                            temp_item.append(item)
                    dic[key][name]['药方'][i]['临时又方']=temp_item

# %%
filename='test6.1_6.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i] and con[i]['临时又方']!=[]:
                    temp_item=[]
                    for item in con[i]['临时又方']:
                        if len(item)==1:
                            if '又方' in dic[key][name]['药方'][i]:
                                temp_dic={}
                                temp_dic['用法']=item[0].replace('又方','')
                                dic[key][name]['药方'][i]['又方'].append(temp_dic)
                            else:
                                dic[key][name]['药方'][i]['又方']=[]
                                temp_dic={}
                                temp_dic['用法']=item[0].replace('又方','')
                                dic[key][name]['药方'][i]['又方'].append(temp_dic)
                        else:
                            temp_item.append(item)
                    dic[key][name]['药方'][i]['临时又方']=temp_item

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i] and con[i]['临时又方']!=[]:
                    temp_item=[]
                    for item in con[i]['临时又方']:
                        if len(item)==3:
                            temp_dic={}
                            if '治' in item[0]:
                                temp_dic['主治']=item[0].replace('又方','').strip()
                            elif '】'==item[0][-1]:
                                temp_dic['方名']=item[0].replace('又方','').strip()
                            temp_dic['中药剂量']=item[1]
                            temp_dic['用法']=item[2]
                            
                            if '又方' in dic[key][name]['药方'][i]:
                                dic[key][name]['药方'][i]['又方'].append(temp_dic)
                            else:
                                dic[key][name]['药方'][i]['又方']=[]
                                dic[key][name]['药方'][i]['又方'].append(temp_dic)
                        else:
                            temp_item.append(item)
                    dic[key][name]['药方'][i]['临时又方']=temp_item

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for i in range(0,len(con)):
                if '临时又方' in con[i] and con[i]['临时又方']==[]:
                    del dic[key][name]['药方'][i]['临时又方']

# %%
filename='test6.1_6.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# ## 切分中药和剂量

# %% [markdown]
# 需要切分的键 中药剂量 后药 又方里的中药剂量

# %%
import pandas as pd

# %%
dd=pd.read_csv('中药词典.csv')

# %%
dd_list=list(dd['n.name'])

# %%
#读取json中爬取的数据
with open('test6.1_6.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
#读取json中爬取的数据
with open('test6.1_7.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '中药剂量' in item and '临时中药剂量' in item:
                    del dic[key][name]['药方'][con_i]['中药剂量']

# %%
def change_split():
    for key in dic.keys():
        for name in dic[key].keys():
            if '药方' in dic[key][name]:
                con=dic[key][name]['药方']
                for con_i in range(0,len(con)):
                    item=con[con_i]
                    if '中药剂量' in item and '临时中药剂量' not in item:
                        temp=item['中药剂量'].split('】')
                        tt=[]
                        for i in temp:
                            if type(i.split())==str:
                                tt.append(i.split())
                            else:
                                tt.extend(i.split())
                        for index in range(0,len(tt)):
                            if '【' in tt[index]:
                                ii=tt[index].index('【')
                                if len(tt[index][:ii])>=4:
                                    if tt[index][:ii] in dd_list or tt[index][:ii]=='生干地黄' or tt[index][:ii]=='赤脚蜈蚣' or tt[index][:ii]=='猪牙皂角' or tt[index][:ii]=='生天南星':
                                        continue
                                    else:
                                        print(tt[index])
                                        sp=input()
                                        if sp=='n':
                                            pass
                                        elif sp=='q':
                                            return
                                        else:
                                            spl=tt[index].index(sp)
                                            tt[index]=[tt[index][:spl],tt[index][spl:]]
                                        print(' ')
                            else:
                                if len(tt[index])>=4:
                                    if tt[index] in dd_list or tt[index]=='生干地黄' or tt[index]=='赤脚蜈蚣' or tt[index]=='猪牙皂角' or tt[index]=='生天南星':
                                        continue
                                    else:
                                        print(tt[index])
                                        sp=input()
                                        if sp=='n':
                                            pass
                                        elif sp=='q':
                                            return
                                        else:
                                            spl=tt[index].index(sp)
                                            tt[index]=[tt[index][:spl],tt[index][spl:]]
                                        print(' ')
                        print(tt)
                        dic[key][name]['药方'][con_i]['临时中药剂量']=tt

# %%
change_split()
# Out:
# 桞木空中屑【二升
# n
#
# ['桞木空中屑【二升', '蒴藋根【切二升', '盐【二合', '栌木【切一升']
# ['枳实【去穣炒黄两片', '芍药【一分']
# ['石南叶【一握', '蜀椒【去目及闭口者炒出汗半两']
# ['牛蒡子', '浮萍']
# 白敛鸡舌香
# n
#
# ['青木香【九铢', '麝香【六铢', '漏芦【各半两', '升麻', '黄芩', '白敛鸡舌香', '熏陆香', '沉香', '防风', '秦艽', '麻黄【各一两', '枳实【一两半', '大黄【一两八铢']
# 白薇浮萍【各一两
# 浮萍【
#
# ['枳实【一两', '菊花', '蛇床子', '防风', '蒺防子', ['白薇', '浮萍【各一两'], '天雄', '麻黄', '漏芦【各半两']
# ['姜黄', '荆芥', '黄连', '土朱', '赤小豆', '烂石膏【等分']
# ['胡粉【一两', '苦参【一两']
# ['犀角屑', '乌蛇肉【半两酒浸去皮骨', '天麻', '白附子', '白僵蚕【各半两微炒以上各捣为细末次入', '朱砂', '麝香', '龙脑【各一钱研']
# ['淡竹\uecb5【一升二合', '葛根汁【一升五合', '牛黄【豆大三颗研']
# ['牛蒡子【炒六两', '荆芥穗【一两', '防风', '甘草【炙', '升麻【各一两半']
# ['寒水石【十六铢', '石膏【十三铢', '蓝青【十二铢冬用干者', '犀角【八铢', '柴胡【八铢', '知母【十铢', '羚羊角【六铢', '杏仁【八铢', '芍药', '黄芩【各七铢', '栀子【二铢', '竹\uecb5【一升', '生葛汁【四合澄清', '蜜【二升']
# ['大黄', '甘草', '当归', '芎防', '白芷', '独活', '黄芩', '芍药', '升麻', '沉香', '青木香', '木兰皮【各一两', '芒硝']
# 赤芍药生地黄
# 生地黄
#
# 烂石膏栀子仁【各半两
# 栀子仁
#
# ['白芷', '柴胡', '知母', '杏仁【去皮', '川芎', ['赤芍药', '生地黄'], '川升麻', '生甘草【各一分', '干葛【一分', ['烂石膏', '栀子仁【各半两'], '蓝叶【日干一分']
# ...

# %%
filename='test6.1_7.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
def change_split2():
    for key in dic.keys():
        for name in dic[key].keys():
            if '药方' in dic[key][name]:
                con=dic[key][name]['药方']
                for con_i in range(0,len(con)):
                    item=con[con_i]
                    if '中药剂量' in item and '临时中药剂量' not in item:
                        temp=item['中药剂量'].split('】')
                        tt=[]
                        for i in temp:
                            if type(i.split())==str:
                                tt.append(i.split())
                            else:
                                tt.extend(i.split())
                        flag=0
                        for index in range(0,len(tt)):
                            if '【' in tt[index]:
                                ii=tt[index].index('【')
                                if len(tt[index][:ii])>=4:
                                    if tt[index][:ii] in dd_list or tt[index][:ii]=='生干地黄' or tt[index][:ii]=='赤脚蜈蚣' or tt[index][:ii]=='猪牙皂角' or tt[index][:ii]=='生天南星':
                                        flag=1
                                        continue
                                    else:
                                        pass
                            else:
                                if len(tt[index])>=4:
                                    if tt[index] in dd_list or tt[index]=='生干地黄' or tt[index]=='赤脚蜈蚣' or tt[index]=='猪牙皂角' or tt[index]=='生天南星':
                                        flag=1
                                        continue
                                    else:
                                        pass
                        if flag==1:
                            dic[key][name]['药方'][con_i]['临时中药剂量']=tt

# %%
change_split2()

# %%
filename='test6.1_7.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1_7.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '后药' in item:
                    temp=item['后药'].split('】')
                    tt=[]
                    for i in temp:
                        if type(i.split())==list:
                            tt.extend(i.split())
                        else:
                            tt.append(i.split())
                    dic[key][name]['药方'][con_i]['后药']=tt

# %%
filename='test6.1_8.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '又方' in item:
                    you=item['又方']
                    for i in range(0,len(you)):
                        you_dic=you[i]
                        if '中药剂量' in you_dic:
                            temp=you_dic['中药剂量'].split('】')
                            tt=[]
                            for inside in temp:
                                if type(inside.split())==list:
                                    tt.extend(inside.split())
                                else:
                                    tt.append(inside.split())
                            #print(you_dic['中药剂量'])
                            #print(tt)
                            #print(' ')
                            dic[key][name]['药方'][con_i]['又方'][i]['临时中药剂量']=tt
                            del dic[key][name]['药方'][con_i]['又方'][i]['中药剂量']

# %%
filename='test6.1_8.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %% [markdown]
# # 分对应剂量

# %%
#读取json中爬取的数据
with open('test6.1_8.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '临时中药剂量' in item:
                    zhong=item['临时中药剂量']
                    temp=[]
                    for zh_index in range(0,len(zhong)):
                        if type(zhong[zh_index])==list:
                            temp.extend(zhong[zh_index])
                        else:
                            temp.append(zhong[zh_index])
                    dic[key][name]['药方'][con_i]['临时中药剂量']=temp

# %%
filename='test6.1_9.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)

# %%
#读取json中爬取的数据
with open('test6.1_9.json',encoding="utf-8") as file_obj:
    dic=json.load(file_obj)

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '临时中药剂量' in item:
                    zhong=item['临时中药剂量']
                    #print(zhong)
                    for zh_index in range(0,len(zhong)):
                        zh=zhong[zh_index]
                        if '各' in zh and '以上各' not in zh and '已上各' not in zh:
                            insert_index=zh.index('各')
                            insert=zh[insert_index+1:]
                            zhong[zh_index]=zhong[zh_index].replace('各','')
                            for j in range(zh_index-1,-1,-1):
                                if '【' in zhong[j]:
                                    if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                        zhong[j]=zhong[j]+insert
                                    else:
                                        break
                                else:
                                    zhong[j]=zhong[j]+'【'+insert
                        elif '以上各' in zh:
                            insert_index=zh.index('以上各')
                            insert=zh[insert_index+3:]
                            zhong[zh_index]=zhong[zh_index].replace('以上各','')
                            for j in range(zh_index-1,-1,-1):
                                if '【' in zhong[j]:
                                    if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                        zhong[j]=zhong[j]+insert
                                    else:
                                        break
                                else:
                                    zhong[j]=zhong[j]+'【'+insert
                        elif '已上各' in zh:
                            insert_index=zh.index('已上各')
                            insert=zh[insert_index+3:]
                            zhong[zh_index]=zhong[zh_index].replace('已上各','')
                            for j in range(zh_index-1,-1,-1):
                                if '【' in zhong[j]:
                                    if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                        zhong[j]=zhong[j]+insert
                                    else:
                                        break
                                else:
                                    zhong[j]=zhong[j]+'【'+insert
                    #print(zhong)
                    zhong_dic={}
                    for i in zhong:
                        if '【' in i:
                            i_index=i.index('【')
                            zhong_dic[i[:i_index]]=i[i_index+1:]
                        else:
                            zhong_dic[i]='无'
                    dic[key][name]['药方'][con_i]['中药及其剂量']=zhong_dic
                    del dic[key][name]['药方'][con_i]['临时中药剂量']

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '后药' in item:
                    zhong=item['后药']
                    #print(zhong)
                    for zh_index in range(0,len(zhong)):
                        zh=zhong[zh_index]
                        if '各' in zh and '以上各' not in zh and '已上各' not in zh:
                            insert_index=zh.index('各')
                            insert=zh[insert_index+1:]
                            zhong[zh_index]=zhong[zh_index].replace('各','')
                            for j in range(zh_index-1,-1,-1):
                                if '【' in zhong[j]:
                                    if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                        zhong[j]=zhong[j]+insert
                                    else:
                                        break
                                else:
                                    zhong[j]=zhong[j]+'【'+insert
                        elif '以上各' in zh:
                            insert_index=zh.index('以上各')
                            insert=zh[insert_index+3:]
                            zhong[zh_index]=zhong[zh_index].replace('以上各','')
                            for j in range(zh_index-1,-1,-1):
                                if '【' in zhong[j]:
                                    if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                        zhong[j]=zhong[j]+insert
                                    else:
                                        break
                                else:
                                    zhong[j]=zhong[j]+'【'+insert
                        elif '已上各' in zh:
                            insert_index=zh.index('已上各')
                            insert=zh[insert_index+3:]
                            zhong[zh_index]=zhong[zh_index].replace('已上各','')
                            for j in range(zh_index-1,-1,-1):
                                if '【' in zhong[j]:
                                    if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                        zhong[j]=zhong[j]+insert
                                    else:
                                        break
                                else:
                                    zhong[j]=zhong[j]+'【'+insert
                    #print(zhong)
                    zhong_dic={}
                    for i in zhong:
                        if '【' in i:
                            i_index=i.index('【')
                            zhong_dic[i[:i_index]]=i[i_index+1:]
                        else:
                            zhong_dic[i]='无'
                    dic[key][name]['药方'][con_i]['后药']=zhong_dic

# %%
for key in dic.keys():
    for name in dic[key].keys():
        if '药方' in dic[key][name]:
            con=dic[key][name]['药方']
            for con_i in range(0,len(con)):
                item=con[con_i]
                if '又方' in item:
                    you=item['又方']
                    for you_index in range(0,len(you)):
                        if '临时中药剂量' in you[you_index]:
                            zhong=you[you_index]['临时中药剂量']
                            temp=[]
                            #print(zhong)
                            for zh_index in range(0,len(zhong)):
                                zh=zhong[zh_index]
                                if '各' in zh and '以上各' not in zh and '已上各' not in zh:
                                    insert_index=zh.index('各')
                                    insert=zh[insert_index+1:]
                                    zhong[zh_index]=zhong[zh_index].replace('各','')
                                    for j in range(zh_index-1,-1,-1):
                                        if '【' in zhong[j]:
                                            if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                                zhong[j]=zhong[j]+insert
                                            else:
                                                break
                                        else:
                                            zhong[j]=zhong[j]+'【'+insert
                                elif '以上各' in zh:
                                    insert_index=zh.index('以上各')
                                    insert=zh[insert_index+3:]
                                    zhong[zh_index]=zhong[zh_index].replace('以上各','')
                                    for j in range(zh_index-1,-1,-1):
                                        if '【' in zhong[j]:
                                            if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                                zhong[j]=zhong[j]+insert
                                            else:
                                                break
                                        else:
                                            zhong[j]=zhong[j]+'【'+insert
                                elif '已上各' in zh:
                                    insert_index=zh.index('已上各')
                                    insert=zh[insert_index+3:]
                                    zhong[zh_index]=zhong[zh_index].replace('已上各','')
                                    for j in range(zh_index-1,-1,-1):
                                        if '【' in zhong[j]:
                                            if '半' not in zhong[j] and '一' not in zhong[j] and '二' not in zhong[j] and '三' not in zhong[j] and '四' not in zhong[j] and '五' not in zhong[j] and '六' not in zhong[j] and '七' not in zhong[j] and '八' not in zhong[j] and '九' not in zhong[j] and '十' not in zhong[j] and  '两' not in zhong[j] and '分' not in zhong[j] and '钱' not in zhong[j] and '字' not in zhong[j] and '各' not in zhong[j]:
                                                zhong[j]=zhong[j]+insert
                                            else:
                                                break
                                        else:
                                            zhong[j]=zhong[j]+'【'+insert
                            #print(zhong)
                            zhong_dic={}
                            for i in zhong:
                                if '【' in i:
                                    i_index=i.index('【')
                                    zhong_dic[i[:i_index]]=i[i_index+1:]
                                else:
                                    zhong_dic[i]='无'
                            dic[key][name]['药方'][con_i]['又方'][you_index]['中药及其剂量']=zhong_dic
                            del dic[key][name]['药方'][con_i]['又方'][you_index]['临时中药剂量']

# %%
filename='test6.2.json'
with open(filename,'w',encoding='utf-8') as file_obj:
    json.dump(dic,file_obj,ensure_ascii=False,indent = 4)
